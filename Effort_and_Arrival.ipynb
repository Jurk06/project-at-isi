# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import warnings
warnings.filterwarnings('ignore')

# %%
import io
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1f4fdfb9-0a3f-4d49-82a0-b968ad691167" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f4fdfb9-0a3f-4d49-82a0-b968ad691167">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Effort and Arrival.xlsx to Effort and Arrival.xlsx

# %%
df=pd.read_excel(io.BytesIO(uploaded['Effort and Arrival.xlsx']))
df.head()
# Out:
#    Job Level of the employee  ...  Service Domain type
# 0                          3  ...           App suport
# 1                          3  ...           App suport
# 2                          3  ...     Database Support
# 3                          3  ...           App suport
# 4                          3  ...           App suport
#
# [5 rows x 6 columns]

# %%
x1 = df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Medium') & (df['Service Domain type']=='App suport')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x1, x='Effort', binwidth=3, kde=True)
plt.show()

# %%
q1=x1.quantile(0.25)
q3=x1.quantile(0.75)
iqr=q3-q1

# %%
((x1<(q1-1.5*iqr)) | (x1>(q3+1.5*iqr))).sum()
# Out:
# # of years of experience     19
# Complexity                    0
# Effort                       33
# ITILProcessType               0
# Job Level of the employee    52
# Service Domain type           0
# dtype: int64

# %%
x1['Effort'].skew()
# Out:
# 1.9055278677677343

# %% [markdown]
# *  If skewness is less than -1 or greater than 1, the distribution is highly skewed.
# *  If skewness is between -1 and -0.5 or between 0.5 and 1, the distribution is moderately skewed.
# * If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.

# %%
x1['Effort'].kurtosis()
# Out:
# 3.5328343485830898

# %%
x1['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    343.000000
# mean     121.335277
# std      122.810919
# min        7.000000
# 10%       25.000000
# 20%       35.000000
# 25%       40.000000
# 30%       45.000000
# 40%       55.000000
# 50%       78.000000
# 60%      102.400000
# 70%      130.000000
# 75%      149.000000
# 80%      175.000000
# 90%      296.600000
# 95%      379.600000
# 100%     610.000000
# max      610.000000
# Name: Effort, dtype: float64

# %% [markdown]
# # "Release Management Vs Medium Vs Database Support"

# %%
x2= df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Medium') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x2, x='Effort', binwidth=30, kde=True)
plt.title("Release Management Vs Medium Vs Database Support")
plt.show()

plt.figure(figsize=(10,5))
sns.boxplot(data=x1, x='Effort')
plt.show()

# %%
x2['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count     41.000000
# mean      99.780488
# std       78.262862
# min        8.000000
# 10%       33.000000
# 20%       42.000000
# 25%       49.000000
# 30%       52.000000
# 40%       74.000000
# 50%       85.000000
# 60%       92.000000
# 70%      102.000000
# 75%      113.000000
# 80%      125.000000
# 90%      188.000000
# 95%      269.000000
# 100%     358.000000
# max      358.000000
# Name: Effort, dtype: float64

# %% [markdown]
# # Release Management Vs Simple Vs App Support

# %%
x3= df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Simple') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x3, x='Effort', binwidth=30, kde=True)
plt.title("Release Management Vs Simple Vs App Support")
plt.show()

# %% [markdown]
# # Release Management Vs Simple Vs Database Support

# %%
x4= df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Simple') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x4, x='Effort', binwidth=30, kde=True)
plt.title("Release Management Vs Simple Vs Database Support")
plt.show()

# %%
x4['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count     17.000000
# mean      78.058824
# std       73.006396
# min        6.000000
# 10%       20.600000
# 20%       28.000000
# 25%       28.000000
# 30%       28.000000
# 40%       39.800000
# 50%       48.000000
# 60%       58.800000
# 70%       88.600000
# 75%       95.000000
# 80%      131.000000
# 90%      183.000000
# 95%      236.200000
# 100%     245.000000
# max      245.000000
# Name: Effort, dtype: float64

# %% [markdown]
# # Release Management Vs Complex Vs App Support

# %%
x5= df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Complex') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x5, x='Effort', binwidth=30, kde=True)
plt.title("Release Management Vs Complex Vs App Support")
plt.show()

# %%
x5['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x6= df[ (df['ITILProcessType']=='Release Management') & (df['Complexity']=='Complex') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x6, x='Effort', binwidth=30, kde=True)
plt.title("Release Management Vs Complex Vs database Support")
plt.show()

# %%
x6['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count      4.000000
# mean     189.000000
# std      156.731192
# min       71.000000
# 10%       88.400000
# 20%      105.800000
# 25%      114.500000
# 30%      123.200000
# 40%      130.400000
# 50%      132.500000
# 60%      134.600000
# 70%      164.400000
# 75%      207.000000
# 80%      249.600000
# 90%      334.800000
# 95%      377.400000
# 100%     420.000000
# max      420.000000
# Name: Effort, dtype: float64

# %%
x7= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Medium') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x7, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs medium Vs App Support")
plt.show()

# %%
x7['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x8= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Medium') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x8, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs medium Vs Database Support")
plt.show()

# %%
x8['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    307.000000
# mean     105.931596
# std       95.929808
# min        5.000000
# 10%       25.600000
# 20%       34.200000
# 25%       42.000000
# 30%       45.800000
# 40%       58.800000
# 50%       75.000000
# 60%       92.600000
# 70%      121.800000
# 75%      139.000000
# 80%      159.800000
# 90%      228.400000
# 95%      292.900000
# 100%     576.000000
# max      576.000000
# Name: Effort, dtype: float64

# %%
sns.scatterplot(data=x8, x="# of years of experience", y="Effort")

# %%
x9= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Simple') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x9, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs Simple Vs App Support")
plt.show()

# %%
x9['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x10= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Simple') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x10, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs Simple Vs Database Support")
plt.show()

# %%
x10['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    1107.000000
# mean       69.562782
# std        52.137463
# min         5.000000
# 10%        23.000000
# 20%        31.000000
# 25%        34.000000
# 30%        36.800000
# 40%        43.000000
# 50%        52.000000
# 60%        62.000000
# 70%        76.200000
# 75%        90.000000
# 80%       100.000000
# 90%       151.400000
# 95%       189.000000
# 100%      250.000000
# max       250.000000
# Name: Effort, dtype: float64

# %%
sns.scatterplot(data=x10, x="# of years of experience", y="Effort")

# %%
x11= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Complex') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x11, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs Complex Vs App Support")
plt.show()

# %%
x11['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x12= df[ (df['ITILProcessType']=='Service Request') & (df['Complexity']=='Complex') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x12, x='Effort', binwidth=30, kde=True)
plt.title("Service Request Vs Complex Vs Database Support")
plt.show()

# %%
df['ITILProcessType'].unique()
# Out:
# array(['Release Management', 'Service Request', 'Incident Management'],
#       dtype=object)

# %%
x12['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count     28.000000
# mean     103.642857
# std       81.618904
# min       19.000000
# 10%       37.400000
# 20%       50.200000
# 25%       58.750000
# 30%       64.100000
# 40%       67.600000
# 50%       70.500000
# 60%       84.800000
# 70%      111.500000
# 75%      121.750000
# 80%      149.800000
# 90%      189.700000
# 95%      290.600000
# 100%     345.000000
# max      345.000000
# Name: Effort, dtype: float64

# %%
x13= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Simple') & (df['Service Domain type']=='App Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x13, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Simple Vs App Support")
plt.show()

# %%
x13['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x14= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Simple') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x14, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Simple Vs Database Support")
plt.show()

# %%
x14['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    1770.000000
# mean       56.498305
# std        53.403635
# min         1.000000
# 10%        15.000000
# 20%        20.000000
# 25%        22.000000
# 30%        24.000000
# 40%        28.000000
# 50%        32.500000
# 60%        42.000000
# 70%        59.300000
# 75%        71.000000
# 80%        87.200000
# 90%       140.000000
# 95%       185.000000
# 100%      250.000000
# max       250.000000
# Name: Effort, dtype: float64

# %%
x15= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Medium') & (df['Service Domain type']=='App Support')]
x16= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Medium') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x15, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Medium Vs App Support")
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=x16, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Medium Vs Database Support")
plt.show()

# %%
x17= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Complex') & (df['Service Domain type']=='App Support')]
x18= df[ (df['ITILProcessType']=='Incident Management') & (df['Complexity']=='Complex') & (df['Service Domain type']=='Database Support')]

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=x17, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Complex Vs App Support")
plt.show()
plt.figure(figsize=(10,5))
sns.histplot(data=x18, x='Effort', binwidth=30, kde=True)
plt.title("Incident Management Vs Complex Vs Database Support")
plt.show()

# %%
x17['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 10%      NaN
# 20%      NaN
# 25%      NaN
# 30%      NaN
# 40%      NaN
# 50%      NaN
# 60%      NaN
# 70%      NaN
# 75%      NaN
# 80%      NaN
# 90%      NaN
# 95%      NaN
# 100%     NaN
# max      NaN
# Name: Effort, dtype: float64

# %%
x18['Effort'].describe(percentiles=[0.1,0.2,0.25,0.3,0.4,0.5,0.6,0.7,0.75,0.8,0.9,0.95,1])
# Out:
# count     55.000000
# mean     145.745455
# std      120.445349
# min       16.000000
# 10%       40.400000
# 20%       55.800000
# 25%       58.000000
# 30%       69.200000
# 40%       81.200000
# 50%      102.000000
# 60%      130.800000
# 70%      183.000000
# 75%      192.000000
# 80%      215.000000
# 90%      317.000000
# 95%      416.300000
# 100%     544.000000
# max      544.000000
# Name: Effort, dtype: float64
